# %%
import pandas as pd
from typing import Union
import pymongo
# from pymongo import MongoClient
pymongo.version
# Out:
# '3.6.1'

# %%
def read_credentials(file_path : str = './data/credentials.txt') -> str:
    '''
    read password and dbname from file to prepare string to pymongo.mongo_client.MongoClient
    # Insert and View Data in Your Cluster -> 
    # https://docs.atlas.mongodb.com/tutorial/insert-data-into-your-cluster/
    
    :Parameters:
    
    input
        - :file_path: file path to credentials to mongo CLUSTER
    return
        - :connect_mongo_string: mongo's string to CLUSTER connection via application
    '''
    import json
    with open(file_path, encoding='utf-8', mode='r') as f:
        json_credentials_dict = json.load(f)
        connect_mongo_string = json_data['mongo_string'].format_map(json_data)
        return connect_mongo_string

# %%
def db_connector(connect_mongo_string : str) -> pymongo.mongo_client.MongoClient:
    '''
    connects to cloud database endpoint. connects to CLUSTER and return pymongo.mongo_client.MongoClient or error text
    # Insert and View Data in Your Cluster -> 
    # https://docs.atlas.mongodb.com/tutorial/insert-data-into-your-cluster/
    
    :Parameters:
    
    input
        - :connect_mongo_string: mongo's string to CLUSTER connection via application
    return
        - :client: pymongo.mongo_client.MongoClient
    '''
    if connect_mongo_string is not None: 
        try:
            client = pymongo.MongoClient(mongo_string)
            client.admin.command('replSetGetStatus')['ok']
            return client
        except pymongo.errors.OperationFailure:
            print(' bad auth Authentication failed.')

# %%
def insert_items(collection : pymongo.collection.Collection, container : Union[pd.DataFrame, dict], one : bool = True):
    '''
    insert elements from container to cloud database. get DATABASE.COLLECTION and insert data iterating over container
    # Insert and View Data in Your Cluster -> 
    # https://docs.atlas.mongodb.com/tutorial/insert-data-into-your-cluster/
    
    :Parameters:
    
    input
        - :collection: mongo's DATABASE.COLLECTION
        - :container: DataFrame or dict 
    return
        - :items: container to cloud database
        - :inserted_ids: container of unique ids
    '''
    for item in container:
        inserted_item_object = collection.insert_one(item)
        print(inserted_item_object.inserted_id)

# %%
def get_items(collection : pymongo.collection.Collection):
    '''
    find all elements from cloud database. get DATABASE.COLLECTION and iterate with cursor
    # Insert and View Data in Your Cluster -> 
    # https://docs.atlas.mongodb.com/tutorial/insert-data-into-your-cluster/
    
    :Parameters:
    
    input
        - :collection: mongo's DATABASE.COLLECTION
    return
        - :items: container with all items from cloud database
    '''
    db_cursor = collection.find({})
    for item in db_cursor:
        print(item)

# %%
mongo_string = read_credentials()

# %%
client = db_connector(mongo_string)

# %%
db_database = client.crimes
detroit_collection = db_database.detroit

# %%
import datetime
personDocument = {
  "name": { "first": "Alan", "last": "Turing II, Jr." },
  "birth": datetime.datetime(1912, 6, 23),
  "death": datetime.datetime(1954, 6, 7),
  "contribs": [ "Turing machine", "Turing test", "Turingery" ],
  "views": 125000012111
}

# %%
insert_items(collection=detroit_collection, container=[personDocument])
# Out:
# 5eefd4f98726e30a40d7174e

# %%
get_items(detroit_collection)
# Out:
# {'_id': ObjectId('5eefd4f98726e30a40d7174e'), 'name': {'first': 'Alan', 'last': 'Turing II, Jr.'}, 'birth': datetime.datetime(1912, 6, 23, 0, 0), 'death': datetime.datetime(1954, 6, 7, 0, 0), 'contribs': ['Turing machine', 'Turing test', 'Turingery'], 'views': 125000012111}

# %% [markdown]
# ***

# %%
df = pd.read_csv('data/RMS_Crime_Incidents2016_modified.csv', index_col=0)
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (9,16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
memory_usege = df.memory_usage().sum() / (1024 * 1024)

# %%
print('App. file size if: {0} MB; shape is {1}, rows*cols;'.format(memory_usege.round(2), df.shape))
# Out:
# App. file size if: 63.01 MB; shape is (266420, 30), rows*cols;

# %%
df.head()
# Out:
#            X          Y  crime_id  report_number                     address  \
# 0 -83.045744  42.337435   3057974     1705020116       Brush St & Madison St
# 1 -83.152200  42.441119   3018981     1701280248  Chippewa St & Greenlawn St
# 2 -83.143470  42.334414   3251044     1808150108       McGraw St & Lumley St
# 3 -83.013835  42.346181   3393605     1908050159    E Lafayette St & Leib St
# 4 -83.156023  42.445779   3004324     1612200136   8 Mile Rd & Cherrylawn St
#
#        offense_description offense_category  state_offense_code arrest_charge  \
# 0  INTIMIDATION / STALKING          ASSAULT                1303         13003
# 1                    ARSON         BURGLARY                2201         22001
# 2          LARCENY - OTHER          LARCENY                2307         23007
# 3          LARCENY - OTHER          LARCENY                2307         23007
# 4            FRAUD BY WIRE            FRAUD                2605         26005
#
#         charge_description  ... zip_code  longitude   latitude       oid  \
# 0  INTIMIDATION / STALKING  ...    48226 -83.045744  42.337435  26994990
# 1  BURGLARY - FORCED ENTRY  ...    48221 -83.152200  42.441119  26994991
# 2          LARCENY - OTHER  ...    48210 -83.143470  42.334414  26994992
# 3          LARCENY - OTHER  ...    48207 -83.013835  42.346181  26994993
# 4            FRAUD BY WIRE  ...    48221 -83.156023  42.445779  26994994
#
#    Crime Against      incident_timestamp_dt incident_timestamp_dt_month  \
# 0         Person  2017-05-02 14:00:00-04:00                           5
# 1       Property  2017-01-26 03:30:00-05:00                           1
# 2       Property  2018-08-13 00:30:00-04:00                           8
# 3       Property  2019-08-03 16:00:00-04:00                           8
# 4       Property  2016-11-21 14:20:00-05:00                          11
#
#    incident_timestamp_dt_hour incident_timestamp_dt_day_of_week  \
# 0                          14                                 1
# 1                           3                                 3
# 2                           0                                 0
# 3                          16                                 5
# 4                          14                                 0
#
#    incident_timestamp_dt_day_of_month
# 0                                   2
# 1                                  26
# 2                                  13
# 3                                   3
# 4                                  21
#
# [5 rows x 30 columns]

# %%
{"0": {"X": -83.04574412799997,
  "Y": 42.337435095000046,
  "crime_id": 3057974,
  "report_number": 1705020116,
  "address": "Brush St & Madison St",
  "offense_description": "INTIMIDATION / STALKING",
  "offense_category": "ASSAULT",
  "state_offense_code": 1303,
  "arrest_charge": "13003",
  "charge_description": "INTIMIDATION / STALKING",
  "incident_timestamp": "2017-05-02T18:00:00.000Z",
  "incident_time": "14:00",
  "day_of_week": 2,
  "hour_of_day": 14,
  "year": 2017,
  "scout_car_area": "0312",
  "precinct": "03",
  "block_id": 261635172002033,
  "neighborhood": "Downtown",
  "council_district": 5,
  "zip_code": 48226,
  "longitude": -83.0457441283857,
  "latitude": 42.337435095232294,
  "oid": 26994990,
  "Crime Against": "Person",
  "incident_timestamp_dt": "2017-05-02 14:00:00-04:00",
  "incident_timestamp_dt_month": 5,
  "incident_timestamp_dt_hour": 14,
  "incident_timestamp_dt_day_of_week": 1,
  "incident_timestamp_dt_day_of_month": 2},
 "1": {"X": -83.15220004799994,
  "Y": 42.44111934500006,
  "crime_id": 3018981,
  "report_number": 1701280248,
  "address": "Chippewa St & Greenlawn St",
  "offense_description": "ARSON",
  "offense_category": "BURGLARY",
  "state_offense_code": 2201,
  "arrest_charge": "22001",
  "charge_description": "BURGLARY - FORCED ENTRY",
  "incident_timestamp": "2017-01-26T08:30:00.000Z",
  "incident_time": "03:30",
  "day_of_week": 4,
  "hour_of_day": 3,
  "year": 2017,
  "scout_car_area": "1203",
  "precinct": "12",
  "block_id": 261635390002005,
  "neighborhood": "Garden Homes",
  "council_district": 2,
  "zip_code": 48221,
  "longitude": -83.15220004758409,
  "latitude": 42.441119345347204,
  "oid": 26994991,
  "Crime Against": "Property",
  "incident_timestamp_dt": "2017-01-26 03:30:00-05:00",
  "incident_timestamp_dt_month": 1,
  "incident_timestamp_dt_hour": 3,
  "incident_timestamp_dt_day_of_week": 3,
  "incident_timestamp_dt_day_of_month": 26}}

# %%
df.head(2).T.to_dict()
# Out:
# {0: {'X': -83.04574412799997,
#   'Y': 42.337435095000046,
#   'crime_id': 3057974,
#   'report_number': 1705020116,
#   'address': 'Brush St & Madison St',
#   'offense_description': 'INTIMIDATION / STALKING',
#   'offense_category': 'ASSAULT',
#   'state_offense_code': 1303,
#   'arrest_charge': '13003',
#   'charge_description': 'INTIMIDATION / STALKING',
#   'incident_timestamp': '2017-05-02T18:00:00.000Z',
#   'incident_time': '14:00',
#   'day_of_week': 2,
#   'hour_of_day': 14,
#   'year': 2017,
#   'scout_car_area': '0312',
#   'precinct': '03',
#   'block_id': 261635172002033,
#   'neighborhood': 'Downtown',
#   'council_district': 5,
#   'zip_code': 48226,
#   'longitude': -83.0457441283857,
#   'latitude': 42.337435095232294,
#   'oid': 26994990,
#   'Crime Against': 'Person',
#   'incident_timestamp_dt': '2017-05-02 14:00:00-04:00',
#   'incident_timestamp_dt_month': 5,
#   'incident_timestamp_dt_hour': 14,
#   'incident_timestamp_dt_day_of_week': 1,
#   'incident_timestamp_dt_day_of_month': 2},
#  1: {'X': -83.15220004799994,
#   'Y': 42.44111934500006,
#   'crime_id': 3018981,
#   'report_number': 1701280248,
#   'address': 'Chippewa St & Greenlawn St',
#   'offense_description': 'ARSON',
#   'offense_category': 'BURGLARY',
#   'state_offense_code': 2201,
#   'arrest_charge': '22001',
#   'charge_description': 'BURGLARY - FORCED ENTRY',
#   'incident_timestamp': '2017-01-26T08:30:00.000Z',
#   'incident_time': '03:30',
#   'day_of_week': 4,
#   'hour_of_day': 3,
#   'year': 2017,
#   'scout_car_area': '1203',
#   'precinct': '12',
#   'block_id': 261635390002005,
#   'neighborhood': 'Garden Homes',
#   'council_district': 2,
#   'zip_code': 48221,
#   'longitude': -83.15220004758409,
#   'latitude': 42.441119345347204,
#   'oid': 26994991,
#   'Crime Against': 'Property',
#   'incident_timestamp_dt': '2017-01-26 03:30:00-05:00',
#   'incident_timestamp_dt_month': 1,
#   'incident_timestamp_dt_hour': 3,
#   'incident_timestamp_dt_day_of_week': 3,
#   'incident_timestamp_dt_day_of_month': 26}}

# %%
df.T.head().to_dict()
# Out:
# {0: {'X': -83.04574412799997,
#   'Y': 42.337435095000046,
#   'crime_id': 3057974,
#   'report_number': 1705020116,
#   'address': 'Brush St & Madison St'},
#  1: {'X': -83.15220004799994,
#   'Y': 42.44111934500006,
#   'crime_id': 3018981,
#   'report_number': 1701280248,
#   'address': 'Chippewa St & Greenlawn St'},
#  2: {'X': -83.14346986099997,
#   'Y': 42.33441377200006,
#   'crime_id': 3251044,
#   'report_number': 1808150108,
#   'address': 'McGraw St & Lumley St'},
#  3: {'X': -83.01383484199994,
#   'Y': 42.346180926000045,
#   'crime_id': 3393605,
#   'report_number': 1908050159,
#   'address': 'E Lafayette St & Leib St'},
#  4: {'X': -83.15602290699997,
#   'Y': 42.44577881700008,
#   'crime_id': 3004324,
#   'report_number': 1612200136,
#   'address': '8 Mile Rd & Cherrylawn St'},
#  5: {'X': -83.16660061,
#   'Y': 42.36103858200005,
#   'crime_id': 3076195,
#   'report_number': 1706110226,
#   'address': 'Ellis St & Manor'},
#  6: {'X': -83.04931988099996,
#   'Y': 42.43835011700002,
#   'crime_id': 3084544,
#   'report_number': 1706300119,
#   'address': 'Bloom St & E Lantz St'},
#  7: {'X': -82.97271471199997,
#   'Y': 42.43521612700005,
#   'crime_id': 3477196,
#   'report_number': 2003040132,
#   'address': 'Celestine St & E 7 Mile Rd'},
#  8: {'X': -83.05250284999995,
#   'Y': 42.32735549200004,
#   'crime_id': 3025697,
#   'report_number': 1702150244,
#   'address': '2nd St & W Congress St'},
#  9: {'X': -83.20033141499994,
#   'Y': 42.38931784000005,
#   'crime_id': 3075062,
#   'report_number': 1706080356,
#   'address': 'Kendall St & Montrose St'},
#  10: {'X': -83.19305652799993,
#   'Y': 42.41131815700004,
#   'crime_id': 3117702,
#   'report_number': 1709150215,
#   'address': 'Robson St & Florence St'},
#  11: {'X': -83.16552921399995,
#   'Y': 42.366055274000075,
#   'crime_id': 3332525,
#   'report_number': 1903130066,
#   'address': 'W Chicago St & Pinehurst St'},
#  12: {'X': -83.04201554799994,
#   'Y': 42.331847469000024,
#   'crime_id': 3259801,
#   'report_number': 1809050296,
#   'address': 'Brush St & E Congress St'},
#  13: {'X': -83.19761372499994,
#   'Y': 42.40335032400003,
#   'crime_id': 3395011,
#   'report_number': 1908080215,
#   'address': 'Prest St & Keeler St'},
#  14: {'X': -83.12190664799994,
#   'Y': 42.35317834400007,
#   'crime_id': 3017432,
#   'report_number': 1701250040,
#   'address': 'Larchmont St & Ironwood St'},
#  15: {'X': -83.09678908499995,
#   'Y': 42.31080752200006,
#   'crime_id': 3245380,
#   'report_number': 1808010363,
#   'address': 'N I 75 Service Drive & Junction St'},
#  16: {'X': -83.09273032399994,
#   'Y': 42.32544460500004,
#   'crime_id': 3046880,
#   'report_number': 1704050341,
#   'address': 'Toledo St & Vinewood St'},
#  17: {'X': -83.08618654699995,
#   'Y': 42.38942103400007,
#   'crime_id': 3000716,
#   'report_number': 1612080220,
#   'address': 'Trowbridge St & Calvert St'},
#  18: {'X': -83.08892590899995,
#   'Y': 42.382373263000034,
#   'crime_id': 3043255,
#   'report_number': 1703270402,
#   'address': '3rd St & Edison St'},
#  19: {'X': -83.16336822199997,
#   'Y': 42.373389891000045,
#   'crime_id': 3158913,
#   'report_number': 1712230259,
#   'address': 'Plymouth Rd & Birwood St'},
#  20: {'X': -83.00580671399997,
#   'Y': 42.398226185000055,
#   'crime_id': 3121729,
#   'report_number': 1709250012,
#   'address': 'Armour St & Edgewood Ave'},
#  22: {'X': -83.16141688499994,
#   'Y': 42.44326331800004,
#   'crime_id': 3463899,
#   'report_number': 2001280371,
#   'address': 'Norfolk St & Wyoming St'},
#  23: {'X': -83.12290977799995,
#   'Y': 42.31067550400007,
#   'crime_id': 3215596,
#   'report_number': 1805240301,
#   'address': 'Central St & Navy St'},
#  24: {'X': -82.98643094699997,
#   'Y': 42.436951756000035,
#   'crime_id': 3010748,
#   'report_number': 1701060281,
#   'address': 'Lappin St & Pelkey St'},
#  25: {'X': -83.22107217699994,
#   'Y': 42.35055604100006,
#   'crime_id': 3008545,
#   'report_number': 1701010060,
#   'address': 'Tireman St & Faust Ave'},
#  26: {'X': -82.97036833299995,
#   'Y': 42.43445177800004,
#   'crime_id': 3007758,
#   'report_number': 1612290380,
#   'address': 'Fordham St & MacCrary Ave'},
#  27: {'X': -82.96671567099996,
#   'Y': 42.41125389900003,
#   'crime_id': 3005980,
#   'report_number': 1612240282,
#   'address': 'Longview St & Queen St'},
#  28: {'X': -83.24015017699999,
#   'Y': 42.37635188600007,
#   'crime_id': 3004230,
#   'report_number': 1612190302,
#   'address': 'Stout St & Capitol St'},
#  29: {'X': -82.99283358699995,
#   'Y': 42.44564265500002,
#   'crime_id': 3000880,
#   'report_number': 1612090033,
#   'address': 'Westphalia St & Bringard Dr'},
#  30: {'X': -83.10387287199995,
#   'Y': 42.44207971900005,
#   'crime_id': 3011345,
#   'report_number': 1701080262,
#   'address': 'Derby St & W Remington Ave'},
#  31: {'X': -83.10839743499997,
#   'Y': 42.39350164600006,
#   'crime_id': 3020506,
#   'report_number': 1702020054,
#   'address': 'Woodrow Wilson St & Leslie St'},
#  32: {'X': -83.15868458899995,
#   'Y': 42.40434477600007,
#   'crime_id': 3020851,
#   'report_number': 1702020368,
#   'address': 'Keeler Ave & Kentucky St'},
#  33: {'X': -83.06763224599996,
#   'Y': 42.427307144000046,
#   'crime_id': 3021035,
#   'report_number': 1702030135,
#   'address': 'Revere St & Stockton St'},
#  34: {'X': -82.93934173899999,
#   'Y': 42.362611518000044,
#   'crime_id': 3034068,
#   'report_number': 1703030357,
#   'address': 'Korte St & Lakewood St'},
#  35: {'X': -83.15869204099994,
#   'Y': 42.37668615800004,
#   'crime_id': 3034175,
#   'report_number': 1703040047,
#   'address': 'Wyoming St & Grand River Ave'},
#  36: {'X': -83.02387507699996,
#   'Y': 42.34828321600002,
#   'crime_id': 3016082,
#   'report_number': 1701220173,
#   'address': 'Campau Farms Cir & Prince Hall Dr'},
#  37: {'X': -83.20728478099994,
#   'Y': 42.426669136000044,
#   'crime_id': 3038909,
#   'report_number': 1703160353,
#   'address': 'Saint Marys St & Margareta St'},
#  38: {'X': -83.20457206299993,
#   'Y': 42.41222023700004,
#   'crime_id': 3039595,
#   'report_number': 1703180063,
#   'address': 'Verne St & Rutherford St'},
#  39: {'X': -83.26146754499995,
#   'Y': 42.34642232800008,
#   'crime_id': 3042078,
#   'report_number': 1703240205,
#   'address': 'Sawyer St & Bramell St'},
#  40: {'X': -83.15818537599996,
#   'Y': 42.26419431500005,
#   'crime_id': 3045619,
#   'report_number': 1704020247,
#   'address': 'S Beatrice St & Francis St'},
#  41: {'X': -83.15600632199995,
#   'Y': 42.26317559000006,
#   'crime_id': 3046847,
#   'report_number': 1704050191,
#   'address': 'Francis St & S Ethel St'},
#  42: {'X': -83.16673983299995,
#   'Y': 42.36603089100004,
#   'crime_id': 3047250,
#   'report_number': 1704060244,
#   'address': 'Manor & W Chicago St'},
#  43: {'X': -83.00580116499998,
#   'Y': 42.43261169600004,
#   'crime_id': 3060246,
#   'report_number': 1705050021,
#   'address': 'Eastwood St & Albion St'},
#  44: {'X': -83.08576344399995,
#   'Y': 42.44490247700002,
#   'crime_id': 3061473,
#   'report_number': 1705080069,
#   'address': 'E Winchester Ave & Orleans St'},
#  45: {'X': -83.18495952399995,
#   'Y': 42.411640466000044,
#   'crime_id': 3057155,
#   'report_number': 1704290370,
#   'address': 'Florence St & Ardmore St'},
#  46: {'X': -83.22703982399997,
#   'Y': 42.43879185400005,
#   'crime_id': 3079355,
#   'report_number': 1706180280,
#   'address': 'Fargo St & Avon Ave'},
#  47: {'X': -83.14179805799995,
#   'Y': 42.36080992500007,
#   'crime_id': 3064757,
#   'report_number': 1705150349,
#   'address': 'Burnette St & Dover St'},
#  48: {'X': -82.93229452299995,
#   'Y': 42.41895269700007,
#   'crime_id': 3065290,
#   'report_number': 1705170033,
#   'address': 'Chester St & Neff Ave'},
#  49: {'X': -82.93040731599997,
#   'Y': 42.414010209000025,
#   'crime_id': 3067017,
#   'report_number': 1705200264,
#   'address': 'Linville St & Woodhall St'},
#  50: {'X': -83.13367752999993,
#   'Y': 42.35960092700003,
#   'crime_id': 3061026,
#   'report_number': 1705060362,
#   'address': 'Colfax St & S Martindale St'},
#  51: {'X': -82.94377777999993,
#   'Y': 42.43054861300004,
#   'crime_id': 3070608,
#   'report_number': 1705290088,
#   'address': 'Lakepointe St & Moross Rd'},
#  52: {'X': -83.13359219599994,
#   'Y': 42.308851805000074,
#   'crime_id': 3071362,
#   'report_number': 1705300532,
#   'address': 'Cabot St & W Vernor Hwy'},
#  53: {'X': -83.11077990499997,
#   'Y': 42.30354955000007,
#   'crime_id': 3071499,
#   'report_number': 1705310063,
#   'address': 'W Fort St & Beard St'},
#  54: {'X': -83.18934613299997,
#   'Y': 42.41150125600007,
#   'crime_id': 3070107,
#   'report_number': 1705270289,
#   'address': 'Hubbell St & Florence St'},
#  55: {'X': -83.22355393799995,
#   'Y': 42.44069634200008,
#   'crime_id': 3080375,
#   'report_number': 1706210038,
#   'address': 'Trojan St & Glastonbury Rd'},
#  56: {'X': -83.11989268199994,
#   'Y': 42.31191679400007,
#   'crime_id': 3080829,
#   'report_number': 1706210475,
#   'address': 'N Green St & Navy St'},
#  57: {'X': -83.24494633299997,
#   'Y': 42.40236192500004,
#   'crime_id': 3084458,
#   'report_number': 1706290442,
#   'address': 'Keeler St & Braile St'},
#  58: {'X': -83.05856254599996,
#   'Y': 42.34180877400007,
#   'crime_id': 3085690,
#   'report_number': 1707020373,
#   'address': 'Cass Ave & Temple St'},
#  59: {'X': -82.97271471199997,
#   'Y': 42.43521612700005,
#   'crime_id': 3087204,
#   'report_number': 1707060067,
#   'address': 'Celestine St & E 7 Mile Rd'},
#  60: {'X': -83.06678914099997,
#   'Y': 42.33112871700007,
#   'crime_id': 3083448,
#   'report_number': 1706270471,
#   'address': 'Trumbull St & Church St'},
#  61: {'X': -83.13747933899998,
#   'Y': 42.336817360000055,
#   'crime_id': 3094115,
#   'report_number': 1707220046,
#   'address': 'Chopin St & McGraw St'},
#  62: {'X': -83.22433079099994,
#   'Y': 42.343300602000056,
#   'crime_id': 3093654,
#   'report_number': 1707210046,
#   'address': 'Stahelin Ave & W Warren Ave'},
#  63: {'X': -83.194048604,
#   'Y': 42.36544340500007,
#   'crime_id': 3100166,
#   'report_number': 1708040226,
#   'address': 'W Chicago St & Sussex'},
#  64: {'X': -83.08760986099996,
#   'Y': 42.36082629400005,
#   'crime_id': 3098566,
#   'report_number': 1708010180,
#   'address': 'Hecla St & Marquette St'},
#  65: {'X': -83.18965355899995,
#   'Y': 42.41994965600002,
#   'crime_id': 3104561,
#   'report_number': 1708150050,
#   'address': 'Hubbell St & W Outer Dr'},
#  66: {'X': -82.92716935899993,
#   'Y': 42.41116929900005,
#   'crime_id': 3103840,
#   'report_number': 1708130070,
#   'address': 'Neff Ave & Southampton St'},
#  67: {'X': -83.12518475,
#   'Y': 42.292732830000034,
#   'crime_id': 3104527,
#   'report_number': 1708140412,
#   'address': 'Melville St & Dearborn St'},
#  68: {'X': -83.01422710399999,
#   'Y': 42.386908501000036,
#   'crime_id': 3100537,
#   'report_number': 1708050255,
#   'address': 'Lambert St & Seneca St'},
#  69: {'X': -83.05655350199999,
#   'Y': 42.330145422000044,
#   'crime_id': 3102150,
#   'report_number': 1708090247,
#   'address': 'Abbott St & 3rd St'},
#  70: {'X': -83.076170656,
#   'Y': 42.418597513000066,
#   'crime_id': 3108886,
#   'report_number': 1708240455,
#   'address': 'E McNichols Rd & Mackay St'},
#  71: {'X': -83.19258649899997,
#   'Y': 42.394437819000075,
#   'crime_id': 3110033,
#   'report_number': 1708280003,
#   'address': 'Robson St & Lyndon St'},
#  72: {'X': -83.25056007399995,
#   'Y': 42.40407022200003,
#   'crime_id': 3107990,
#   'report_number': 1708230026,
#   'address': 'Westbrook St & Midland St'},
#  73: {'X': -83.08804028699996,
#   'Y': 42.32333722100003,
#   'crime_id': 3110909,
#   'report_number': 1708290408,
#   'address': '25th St & W Vernor Hwy'},
#  74: {'X': -83.14346986099997,
#   'Y': 42.33441377200006,
#   'crime_id': 3112120,
#   'report_number': 1709010224,
#   'address': 'McGraw St & Lumley St'},
#  75: {'X': -83.00418675899994,
#   'Y': 42.38247433300006,
#   'crime_id': 3115198,
#   'report_number': 1709090096,
#   'address': 'Moffat St & Holcomb Ave'},
#  76: {'X': -83.11277048899994,
#   'Y': 42.39569122000006,
#   'crime_id': 3116386,
#   'report_number': 1709120144,
#   'address': 'Rosa Parks Blvd & Waverly St'},
#  77: {'X': -83.05526498599994,
#   'Y': 42.429683546000035,
#   'crime_id': 3115997,
#   'report_number': 1709110143,
#   'address': 'Healy St & E Hildale St'},
#  78: {'X': -83.16684015199995,
#   'Y': 42.44315124900004,
#   'crime_id': 3119280,
#   'report_number': 1709190187,
#   'address': 'Norfolk St & Mendota St'},
#  79: {'X': -83.13973650499997,
#   'Y': 42.36397738000005,
#   'crime_id': 3128068,
#   'report_number': 1710090299,
#   'address': 'Stoepel St & Westfield St'},
#  80: {'X': -83.07975728499997,
#   'Y': 42.38546437600007,
#   'crime_id': 3125617,
#   'report_number': 1710030429,
#   'address': 'Kenilworth St & John R St'},
#  81: {'X': -83.09657016999991,
#   'Y': 42.37744342100007,
#   'crime_id': 3133103,
#   'report_number': 1710220021,
#   'address': 'Woodrow Wilson St & Clairmount St'},
#  82: {'X': -83.11814370599996,
#   'Y': 42.38725433600007,
#   'crime_id': 3154839,
#   'report_number': 1712110344,
#   'address': 'Highland St & Linwood St'},
#  83: {'X': -83.19833887499998,
#   'Y': 42.42140058900002,
#   'crime_id': 3149969,
#   'report_number': 1711290074,
#   'address': 'Prest St & Thatcher St'},
#  84: {'X': -83.13273775299997,
#   'Y': 42.309200417000056,
#   'crime_id': 3151095,
#   'report_number': 1712010373,
#   'address': 'Lawndale St & W Vernor Hwy'},
#  85: {'X': -82.99682044899998,
#   'Y': 42.382366257000065,
#   'crime_id': 3145806,
#   'report_number': 1711180015,
#   'address': 'E Warren Ave & Cadillac Blvd'},
#  86: {'X': -83.04098148599995,
#   'Y': 42.335605480000034,
#   'crime_id': 3151227,
#   'report_number': 1712020055,
#   'address': 'Monroe St & Saint Antoine St'},
#  87: {'X': -82.92242787799995,
#   'Y': 42.41090188300007,
#   'crime_id': 3152240,
#   'report_number': 1712040408,
#   'address': 'Frankfort St & Marseilles St'},
#  88: {'X': -83.08263474099994,
#   'Y': 42.389741609000055,
#   'crime_id': 3153612,
#   'report_number': 1712080127,
#   'address': 'John R St & Belmont St'},
#  89: {'X': -83.16914124299996,
#   'Y': 42.36598184600007,
#   'crime_id': 3159982,
#   'report_number': 1712270268,
#   'address': 'W Chicago St & Appoline'},
#  90: {'X': -82.93566570499998,
#   'Y': 42.39579617400005,
#   'crime_id': 3164874,
#   'report_number': 1801110198,
#   'address': 'Bremen St & 3 Mile Dr'},
#  91: {'X': -82.96871970199999,
#   'Y': 42.43828097200003,
#   'crime_id': 3162584,
#   'report_number': 1801050011,
#   'address': 'Coram St & Queen St'},
#  92: {'X': -83.22487946999998,
#   'Y': 42.357735302000044,
#   'crime_id': 3163449,
#   'report_number': 1801070220,
#   'address': 'Stahelin Ave & Joy Rd'},
#  93: {'X': -82.96549471699996,
#   'Y': 42.39716190400002,
#   'crime_id': 3170657,
#   'report_number': 1801270240,
#   'address': 'Lakeview St & Southampton St'},
#  94: {'X': -83.05493516199994,
#   'Y': 42.43587684100004,
#   'crime_id': 3175560,
#   'report_number': 1802120007,
#   'address': 'Emery St & Lamont St'},
#  95: {'X': -83.21910431999999,
#   'Y': 42.39619143700002,
#   'crime_id': 3176578,
#   'report_number': 1802150018,
#   'address': 'Ashton Rd & Eaton St'},
#  96: {'X': -83.10948317399999,
#   'Y': 42.395073513000064,
#   'crime_id': 3177239,
#   'report_number': 1802160214,
#   'address': 'Woodrow Wilson St & W Buena Vista St'},
#  97: {'X': -83.22565047199998,
#   'Y': 42.34328605800005,
#   'crime_id': 3194680,
#   'report_number': 1804040006,
#   'address': 'Artesian St & W Warren Ave'},
#  98: {'X': -83.09108519599994,
#   'Y': 42.42497652200007,
#   'crime_id': 3183828,
#   'report_number': 1803070095,
#   'address': 'Cardoni St & E Nevada St'},
#  99: {'X': -83.12781096599997,
#   'Y': 42.410162193000076,
#   'crime_id': 3195335,
#   'report_number': 1804060017,
#   'address': 'Puritan St & Linwood St'},
#  100: {'X': -83.17981057299994,
#   'Y': 42.416598675000046,
#   'crime_id': 3195355,
#   'report_number': 1804050438,
#   'address': 'Schaefer Hwy & W McNichols Rd'},
#  101: {'X': -83.19334089299997,
#   'Y': 42.37638387700008,
#   'crime_id': 3188411,
#   'report_number': 1803190158,
#   'address': 'Castleton St & Coyle St'},
#  102: {'X': -83.13812954299993,
#   'Y': 42.39215357500007,
#   'crime_id': 3205829,
#   'report_number': 1805010250,
#   'address': 'Ewald Cir & Petoskey Ave'},
#  103: {'X': -82.95111131199997,
#   'Y': 42.437297613000055,
#   'crime_id': 3196048,
#   'report_number': 1804070331,
#   'address': 'Kelly Rd & Lappin St'},
#  104: {'X': -83.20384840299994,
#   'Y': 42.394875746000025,
#   'crime_id': 3217218,
#   'report_number': 1805280235,
#   'address': 'Rutherford St & Grand River Ave'},
#  105: {'X': -82.95865019199994,
#   'Y': 42.44913385800004,
#   'crime_id': 3217353,
#   'report_number': 1805290013,
#   'address': 'Carlisle St & Rex St'},
#  106: {'X': -83.00608304999997,
#   'Y': 42.41419088700008,
#   'crime_id': 3214332,
#   'report_number': 1805210355,
#   'address': 'College St & Algonac St'},
#  107: {'X': -83.00776527799998,
#   'Y': 42.36108744200004,
#   'crime_id': 3219619,
#   'report_number': 1806020310,
#   'address': 'Sheridan St & Charlevoix St'},
#  108: {'X': -83.14489596199995,
#   'Y': 42.27587159800004,
#   'crime_id': 3216449,
#   'report_number': 1805260233,
#   'address': 'S Ethel St & S Bassett St'},
#  109: {'X': -83.00432406299996,
#   'Y': 42.410194044000036,
#   'crime_id': 3224071,
#   'report_number': 1806130078,
#   'address': 'Conner St & Sanford St'},
#  110: {'X': -83.09801353699999,
#   'Y': 42.35505698300005,
#   'crime_id': 3225564,
#   'report_number': 1806160330,
#   'address': 'Missouri St & McGraw St'},
#  111: {'X': -83.06719362599993,
#   'Y': 42.40774071900006,
#   'crime_id': 3226196,
#   'report_number': 1806180243,
#   'address': 'Maine St & Halleck St'},
#  112: {'X': -83.19619330199998,
#   'Y': 42.399392840000075,
#   'crime_id': 3231102,
#   'report_number': 1806290389,
#   'address': 'Whitcomb St & Chalfonte St'},
#  113: {'X': -83.10511170299998,
#   'Y': 42.36796799500007,
#   'crime_id': 3228855,
#   'report_number': 1806240343,
#   'address': 'W Philadelphia St & Linwood St'},
#  114: {'X': -83.17725390099997,
#   'Y': 42.43115291200007,
#   'crime_id': 3230577,
#   'report_number': 1806280278,
#   'address': 'W 7 Mile Rd & Littlefield St'},
#  115: {'X': -83.21595292499995,
#   'Y': 42.43908242100008,
#   'crime_id': 3237706,
#   'report_number': 1807140381,
#   'address': 'Oakfield St & Fargo St'},
#  116: {'X': -83.02403174199995,
#   'Y': 42.38884187800004,
#   'crime_id': 3237077,
#   'report_number': 1807130111,
#   'address': 'Townsend St & Saint Thomas St'},
#  117: {'X': -83.00108565099998,
#   'Y': 42.39530233700003,
#   'crime_id': 3245890,
#   'report_number': 1808020386,
#   'address': 'Garland St & Sterritt St'},
#  118: {'X': -83.14175466299997,
#   'Y': 42.441347036000025,
#   'crime_id': 3249749,
#   'report_number': 1808120036,
#   'address': 'Chippewa St & Livernois Ave'},
#  119: {'X': -83.27665725499998,
#   'Y': 42.426608362000024,
#   'crime_id': 3253005,
#   'report_number': 1808200005,
#   'address': 'Clarita St & Dale St'},
#  120: {'X': -82.99719311899997,
#   'Y': 42.41094442800004,
#   'crime_id': 3253034,
#   'report_number': 1808200017,
#   'address': 'Gunston St & Flanders St'},
#  121: {'X': -83.11196193799998,
#   'Y': 42.361778797000056,
#   'crime_id': 3261044,
#   'report_number': 1809080076,
#   'address': 'Montgomery St & Dexter Ave'},
#  122: {'X': -83.08610344299996,
#   'Y': 42.37818284600007,
#   'crime_id': 3260783,
#   'report_number': 1809070110,
#   'address': '3rd St & Gladstone St'},
#  123: {'X': -83.23588088599996,
#   'Y': 42.43686468300007,
#   'crime_id': 3266588,
#   'report_number': 1809180451,
#   'address': 'Pembroke Ave & Annchester Rd'},
#  124: {'X': -83.21925788699998,
#   'Y': 42.33450035300007,
#   'crime_id': 3266139,
#   'report_number': 1809180026,
#   'address': 'Penrod St & Dayton St'},
#  125: {'X': -83.09733303899995,
#   'Y': 42.357341964000064,
#   'crime_id': 3000728,
#   'report_number': 1612080296,
#   'address': 'Marquette St & Linwood St'},
#  126: {'X': -82.99080020799995,
#   'Y': 42.41983152500006,
#   'crime_id': 3274963,
#   'report_number': 1810080426,
#   'address': 'Minden St & Barlow St'},
#  127: {'X': -83.24116659099997,
#   'Y': 42.415106339000026,
#   'crime_id': 3271986,
#   'report_number': 1810010430,
#   'address': 'W McNichols Rd & Kentfield St'},
#  128: {'X': -83.19868770499993,
#   'Y': 42.43045749100002,
#   'crime_id': 3274711,
#   'report_number': 1810080161,
#   'address': 'W 7 Mile Rd & Prest St'},
#  129: {'X': -83.20042167699995,
#   'Y': 42.44272484100002,
#   'crime_id': 3277104,
#   'report_number': 1810140042,
#   'address': 'James Couzens Fwy & Greenfield Rd'},
#  130: {'X': -83.24888193399994,
#   'Y': 42.388434046000036,
#   'crime_id': 3283032,
#   'report_number': 1810280307,
#   'address': 'Blackstone St & Kendall St'},
#  131: {'X': -83.15220004799994,
#   'Y': 42.44111934500006,
#   'crime_id': 3278682,
#   'report_number': 1810170432,
#   'address': 'Chippewa St & Greenlawn St'},
#  132: {'X': -83.01469260499994,
#   'Y': 42.37883098000003,
#   'crime_id': 3286773,
#   'report_number': 1811070041,
#   'address': 'Van Dyke St & Gratiot Ave'},
#  133: {'X': -83.13474093699995,
#   'Y': 42.35062162400004,
#   'crime_id': 3274248,
#   'report_number': 1810070021,
#   'address': 'Barton St & Livernois Ave'},
#  134: {'X': -83.07265627599996,
#   'Y': 42.44038563000004,
#   'crime_id': 3288486,
#   'report_number': 1811110223,
#   'address': 'Mitchell St & E Outer Dr'},
#  135: {'X': -83.00137150299997,
#   'Y': 42.380420711000056,
#   'crime_id': 3293684,
#   'report_number': 1811250308,
#   'address': 'E Warren Ave & Belvidere St'},
#  136: {'X': -83.27832368399999,
#   'Y': 42.414518161000046,
#   'crime_id': 3295212,
#   'report_number': 1811290150,
#   'address': 'W McNichols Rd & Woodbine St'},
#  137: {'X': -83.00459700199998,
#   'Y': 42.43264976200004,
#   'crime_id': 3302914,
#   'report_number': 1812190037,
#   'address': 'Hoover St & Eastwood St'},
#  138: {'X': -83.15666412499998,
#   'Y': 42.40790581600004,
#   'crime_id': 3304857,
#   'report_number': 1812240047,
#   'address': 'Wisconsin St & Pilgrim St'},
#  139: {'X': -83.14295808599995,
#   'Y': 42.33065582800003,
#   'crime_id': 3305789,
#   'report_number': 1812270026,
#   'address': 'Saint Lawrence St & Michigan Ave'},
#  140: {'X': -83.15602290699997,
#   'Y': 42.44577881700008,
#   'crime_id': 3308797,
#   'report_number': 1901030361,
#   'address': '8 Mile Rd & Cherrylawn St'},
#  141: {'X': -83.21595292499995,
#   'Y': 42.43908242100008,
#   'crime_id': 3315152,
#   'report_number': 1901210107,
#   'address': 'Oakfield St & Fargo St'},
#  142: {'X': -83.20350238499998,
#   'Y': 42.33995847800003,
#   'crime_id': 3291362,
#   'report_number': 1811180269,
#   'address': 'Saint Marys St & Whitlock St'},
#  143: {'X': -82.940961557,
#   'Y': 42.40200048900005,
#   'crime_id': 3314486,
#   'report_number': 1901190044,
#   'address': 'Bedford St & E Warren Ave'},
#  144: {'X': -83.215643001,
#   'Y': 42.37227595000007,
#   'crime_id': 3316233,
#   'report_number': 1901240315,
#   'address': 'Archdale St & Plymouth Rd'},
#  145: {'X': -83.16529914999995,
#   'Y': 42.431316081000034,
#   'crime_id': 3316319,
#   'report_number': 1901250037,
#   'address': 'Birwood St & W 7 Mile Rd'},
#  146: {'X': -83.236855656,
#   'Y': 42.38626190100007,
#   'crime_id': 3318689,
#   'report_number': 1902010356,
#   'address': 'Schoolcraft St & Evergreen Rd'},
#  147: {'X': -82.95620557899997,
#   'Y': 42.449175859000036,
#   'crime_id': 3327070,
#   'report_number': 1902250266,
#   'address': 'Redmond St & Carlisle St'},
#  148: {'X': -83.21612183199994,
#   'Y': 42.43011223800004,
#   'crime_id': 3334025,
#   'report_number': 1903160249,
#   'address': 'Harlow St & W 7 Mile Rd'},
#  149: {'X': -83.02426146499994,
#   'Y': 42.43397794500004,
#   'crime_id': 3334069,
#   'report_number': 1903160291,
#   'address': 'Van Dyke St & E 7 Mile Rd'},
#  150: {'X': -83.18733033899997,
#   'Y': 42.391025652000046,
#   'crime_id': 3328540,
#   'report_number': 1903010288,
#   'address': 'Strathmoor St & Intervale St'},
#  151: {'X': -83.14061906399995,
#   'Y': 42.386635970000036,
#   'crime_id': 3343311,
#   'report_number': 1904080334,
#   'address': 'W Davison St & Stoepel St'},
#  152: {'X': -83.16150905199999,
#   'Y': 42.44565368700007,
#   'crime_id': 3343347,
#   'report_number': 1904090014,
#   'address': 'Wyoming St & 8 Mile Rd'},
#  153: {'X': -82.99349339199993,
#   'Y': 42.431111053000045,
#   'crime_id': 3357941,
#   'report_number': 1905140121,
#   'address': 'Linnhurst St & Goulburn St'},
#  154: {'X': -82.96078793599996,
#   'Y': 42.38842821900005,
#   'crime_id': 3359953,
#   'report_number': 1905190126,
#   'address': 'Waveney St & Coplin St'},
#  155: {'X': -83.16766770199995,
#   'Y': 42.38828444400008,
#   'crime_id': 3360019,
#   'report_number': 1905190180,
#   'address': 'Schoolcraft St & Manor'},
#  156: {'X': -83.08978624899999,
#   'Y': 42.38917828500007,
#   'crime_id': 3362393,
#   'report_number': 1905250026,
#   'address': '2nd Blvd & Collingwood St'},
#  157: {'X': -83.12430346799994,
#   'Y': 42.34631066300005,
#   'crime_id': 3347790,
#   'report_number': 1904190350,
#   'address': 'Cobb Pl & Colfax St'},
#  158: {'X': -83.22315995299994,
#   'Y': 42.343312670000046,
#   'crime_id': 3366654,
#   'report_number': 1906030461,
#   'address': 'Brace St & W Warren Ave'},
#  159: {'X': -82.995124418,
#   'Y': 42.37765653200007,
#   'crime_id': 3363347,
#   'report_number': 1905270145,
#   'address': 'Pennsylvania St & E Canfield St'},
#  160: {'X': -83.12740353499998,
#   'Y': 42.34083737700007,
#   'crime_id': 3373819,
#   'report_number': 1906200393,
#   'address': 'Livernois Ave & McGraw St'},
#  161: {'X': -82.99249931299995,
#   'Y': 42.39287302300004,
#   'crime_id': 3380408,
#   'report_number': 1907060072,
#   'address': 'Springfield St & E I 94 Service Drive'},
#  162: {'X': -83.24015017699999,
#   'Y': 42.37635188600007,
#   'crime_id': 3381915,
#   'report_number': 1907090336,
#   'address': 'Stout St & Capitol St'},
#  163: {'X': -82.95516687799993,
#   'Y': 42.428241754000055,
#   'crime_id': 3381984,
#   'report_number': 1907090372,
#   'address': 'Riad St & Morang Dr'},
#  164: {'X': -83.22355987599997,
#   'Y': 42.38656065200007,
#   'crime_id': 3384087,
#   'report_number': 1907150054,
#   'address': 'Schoolcraft St & Greenview Rd'},
#  165: {'X': -83.02426146499994,
#   'Y': 42.43397794500004,
#   'crime_id': 3389985,
#   'report_number': 1907280002,
#   'address': 'Van Dyke St & E 7 Mile Rd'},
#  166: {'X': -83.08260308999998,
#   'Y': 42.378510494000075,
#   'crime_id': 3390044,
#   'report_number': 1907280073,
#   'address': '2nd Ave & Blaine St'},
#  167: {'X': -83.02146733399995,
#   'Y': 42.446187775000055,
#   'crime_id': 3391340,
#   'report_number': 1907300419,
#   'address': 'Conner St & Savage St'},
#  168: {'X': -83.25232848899999,
#   'Y': 42.431066421000025,
#   'crime_id': 3385928,
#   'report_number': 1907180481,
#   'address': 'Cambridge Ave & Westbrook St'},
#  169: {'X': -83.18934613299997,
#   'Y': 42.41150125600007,
#   'crime_id': 3386797,
#   'report_number': 1907210022,
#   'address': 'Hubbell St & Florence St'},
#  170: {'X': -83.11254990899994,
#   'Y': 42.36871238400005,
#   'crime_id': 3393034,
#   'report_number': 1908030299,
#   'address': 'Wildemere St & Gladstone St'},
#  171: {'X': -83.21653962999993,
#   'Y': 42.34336839300004,
#   'crime_id': 3393824,
#   'report_number': 1908050216,
#   'address': 'W Warren Ave & S M 39 Service Drive'},
#  172: {'X': -83.11085559799993,
#   'Y': 42.35558274400006,
#   'crime_id': 3405156,
#   'report_number': 1909010056,
#   'address': 'W Grand Blvd & Tireman St'},
#  173: {'X': -83.11884369399995,
#   'Y': 42.33112622400005,
#   'crime_id': 3407925,
#   'report_number': 1909070252,
#   'address': 'Michigan Ave & Military St'},
#  174: {'X': -83.05422450799993,
#   'Y': 42.42970466700007,
#   'crime_id': 3416329,
#   'report_number': 1909270139,
#   'address': 'Lamont St & E Hildale St'},
#  175: {'X': -83.20958785199997,
#   'Y': 42.352530674000036,
#   'crime_id': 3411081,
#   'report_number': 1909150039,
#   'address': 'Belton Ave & Abington Ave'},
#  176: {'X': -83.16538019999997,
#   'Y': 42.43310284900008,
#   'crime_id': 3418267,
#   'report_number': 1910020022,
#   'address': 'Birwood St & Cambridge Ave'},
#  177: {'X': -83.02184531799999,
#   'Y': 42.36403740000002,
#   'crime_id': 3424998,
#   'report_number': 1910180147,
#   'address': 'Meldrum St & Sylvester St'},
#  178: {'X': -83.22945046299998,
#   'Y': 42.346891407000044,
#   'crime_id': 3420614,
#   'report_number': 1910070364,
#   'address': 'Grandville Ave & Sawyer St'},
#  179: {'X': -83.21839128499995,
#   'Y': 42.44082887400003,
#   'crime_id': 3421963,
#   'report_number': 1910100437,
#   'address': 'Fenmore St & Trojan St'},
#  180: {'X': -83.06981906599998,
#   'Y': 42.44266857400004,
#   'crime_id': 3425202,
#   'report_number': 1910180390,
#   'address': 'Klinger St & E Remington St'},
#  181: {'X': -83.21365255199999,
#   'Y': 42.440951247000044,
#   'crime_id': 3434386,
#   'report_number': 1911100196,
#   'address': 'Gilchrist St & Trojan St'},
#  182: {'X': -82.94027115299998,
#   'Y': 42.39006249200002,
#   'crime_id': 3433558,
#   'report_number': 1911080085,
#   'address': 'Balfour Rd & Brunswick St'},
#  183: {'X': -83.22764692899995,
#   'Y': 42.40088907200004,
#   'crime_id': 3440378,
#   'report_number': 1911260329,
#   'address': 'Fenkell St & Artesian St'},
#  184: {'X': -83.20677891599996,
#   'Y': 42.386891450000064,
#   'crime_id': 3440021,
#   'report_number': 1911260011,
#   'address': 'Schoolcraft St & Mettetal St'},
#  185: {'X': -82.96057639299994,
#   'Y': 42.432443963000026,
#   'crime_id': 3442444,
#   'report_number': 1912020364,
#   'address': 'Faircrest St & Salter St'},
#  186: {'X': -83.25353428899997,
#   'Y': 42.43103952000007,
#   'crime_id': 3439557,
#   'report_number': 1911240238,
#   'address': 'Cambridge Ave & Bentler St'},
#  187: {'X': -83.19635602499993,
#   'Y': 42.403392386000064,
#   'crime_id': 3448297,
#   'report_number': 1912180033,
#   'address': 'Keeler St & Whitcomb St'},
#  188: {'X': -83.15676982199994,
#   'Y': 42.35892755400005,
#   'crime_id': 3448866,
#   'report_number': 1912190131,
#   'address': 'Joy Rd & Kentucky St'},
#  189: {'X': -82.99634438199999,
#   'Y': 42.44191986800007,
#   'crime_id': 3442313,
#   'report_number': 1912020084,
#   'address': 'Barlow St & E State Fair St'},
#  190: {'X': -83.166968877,
#   'Y': 42.37327787700008,
#   'crime_id': 3446070,
#   'report_number': 1912120035,
#   'address': 'Plymouth Rd & Manor'},
#  191: {'X': -83.08776836699997,
#   'Y': 42.43274182500005,
#   'crime_id': 3443735,
#   'report_number': 1912050412,
#   'address': 'Greeley St & E 7 Mile Rd'},
#  192: {'X': -83.126917382,
#   'Y': 42.36664566800005,
#   'crime_id': 3453566,
#   'report_number': 2001010229,
#   'address': 'Cascade St & Joy Rd'},
#  193: {'X': -83.10289431899997,
#   'Y': 42.37513001600007,
#   'crime_id': 3457447,
#   'report_number': 2001110176,
#   'address': 'Clairmount St & 14th St'},
#  194: {'X': -83.15783981699997,
#   'Y': 42.40973882400005,
#   'crime_id': 3457890,
#   'report_number': 2001130041,
#   'address': 'Indiana St & Puritan St'},
#  195: {'X': -83.14587629699997,
#   'Y': 42.433331225000074,
#   'crime_id': 3463216,
#   'report_number': 2001270001,
#   'address': 'Prairie St & Cambridge Ave'},
#  196: {'X': -83.03794355499997,
#   'Y': 42.342367455000044,
#   'crime_id': 3467802,
#   'report_number': 2002070124,
#   'address': 'Russell St & Maple St'},
#  197: {'X': -83.08900999699993,
#   'Y': 42.43269760100002,
#   'crime_id': 3468507,
#   'report_number': 2002090278,
#   'address': 'E 7 Mile Rd & Hull St'},
#  198: {'X': -83.05526498599994,
#   'Y': 42.429683546000035,
#   'crime_id': 3476680,
#   'report_number': 1912010027,
#   'address': 'Healy St & E Hildale St'},
#  199: {'X': -83.22107217699994,
#   'Y': 42.35055604100006,
#   'crime_id': 3016008,
#   'report_number': 1701220016,
#   'address': 'Tireman St & Faust Ave'},
#  200: {'X': -83.16253947899997,
#   'Y': 42.395181483000044,
#   'crime_id': 3473477,
#   'report_number': 2002220287,
#   'address': 'Griggs St & Lyndon St'},
#  201: {'X': -83.26427024499998,
#   'Y': 42.36431287000005,
#   'crime_id': 3476033,
#   'report_number': 2003010193,
#   'address': 'W Chicago St & Beaverland St'},
#  202: {'X': -83.18965355899995,
#   'Y': 42.41994965600002,
#   'crime_id': 3124280,
#   'report_number': 1709300221,
#   'address': 'Hubbell St & W Outer Dr'},
#  203: {'X': -83.20322225599993,
#   'Y': 42.40867000100008,
#   'crime_id': 3153988,
#   'report_number': 1712080416,
#   'address': 'Puritan St & Prevost St'},
#  204: {'X': -83.17434802299994,
#   'Y': 42.37311055900005,
#   'crime_id': 3160989,
#   'report_number': 1712310048,
#   'address': 'Plymouth Rd & Cheyenne St'},
#  205: {'X': -83.13190035299993,
#   'Y': 42.33111916900003,
#   'crime_id': 3299128,
#   'report_number': 1812090190,
#   'address': 'Cecil St & Michigan Ave'},
#  206: {'X': -82.94886678099994,
#   'Y': 42.43303946900005,
#   'crime_id': 3313322,
#   'report_number': 1901160009,
#   'address': 'Laing St & Moross Rd'},
#  207: {'X': -83.19812772799997,
#   'Y': 42.41603278400004,
#   'crime_id': 3334065,
#   'report_number': 1903160294,
#   'address': 'Prest St & W McNichols Rd'},
#  208: {'X': -83.19812772799997,
#   'Y': 42.41603278400004,
#   'crime_id': 3334065,
#   'report_number': 1903160294,
#   'address': 'Prest St & W McNichols Rd'},
#  209: {'X': -83.1850681499999,
#   'Y': 42.36564294900006,
#   'crime_id': 3296327,
#   'report_number': 1812020126,
#   'address': 'W Chicago St & Mark Twain St'},
#  210: {'X': -83.15516401599997,
#   'Y': 42.42244618900003,
#   'crime_id': 3259241,
#   'report_number': 1809040050,
#   'address': 'Cherrylawn St & Thatcher St'},
#  211: {'X': -83.23600053799998,
#   'Y': 42.361126341000045,
#   'crime_id': 3264575,
#   'report_number': 1809140053,
#   'address': 'Cathedral St & Evergreen Rd'},
#  212: {'X': -83.19309801399999,
#   'Y': 42.370312795000075,
#   'crime_id': 3008422,
#   'report_number': 1612310329,
#   'address': 'Elmira St & Coyle St'},
#  213: {'X': -82.99150739699995,
#   'Y': 42.442045774000064,
#   'crime_id': 3019266,
#   'report_number': 1701290191,
#   'address': 'E State Fair St & Fairport St'},
#  214: {'X': -83.00360023299999,
#   'Y': 42.438108879000026,
#   'crime_id': 3009720,
#   'report_number': 1701040068,
#   'address': 'Rowe St & Pinewood St'},
#  215: {'X': -83.04736626299997,
#   'Y': 42.40811381900005,
#   'crime_id': 3027306,
#   'report_number': 1702190266,
#   'address': 'Buffalo St & Talbot St'},
#  216: {'X': -83.12825189499993,
#   'Y': 42.35193607000008,
#   'crime_id': 3000483,
#   'report_number': 1612080042,
#   'address': 'Colfax St & Tireman St'},
#  217: {'X': -83.00699674599997,
#   'Y': 42.44004258700004,
#   'crime_id': 3022680,
#   'report_number': 1702080094,
#   'address': 'Manning St & Runyon St'},
#  218: {'X': -83.26427024499998,
#   'Y': 42.36431287000005,
#   'crime_id': 3023701,
#   'report_number': 1702100175,
#   'address': 'W Chicago St & Beaverland St'},
#  219: {'X': -82.96671567099996,
#   'Y': 42.41125389900003,
#   'crime_id': 3067122,
#   'report_number': 1705210066,
#   'address': 'Longview St & Queen St'},
#  220: {'X': -83.12769384299997,
#   'Y': 42.41016343000007,
#   'crime_id': 3063884,
#   'report_number': 1705130203,
#   'address': 'Puritan St & Linwood St'},
#  221: {'X': -83.01987987799998,
#   'Y': 42.39572648600006,
#   'crime_id': 3064304,
#   'report_number': 1705140277,
#   'address': 'Maxwell St & Marcus Ave'},
#  222: {'X': -83.22662858599993,
#   'Y': 42.43165162700007,
#   'crime_id': 3083458,
#   'report_number': 1706270455,
#   'address': 'Cambridge Ave & Avon Ave'},
#  223: {'X': -83.08220005099997,
#   'Y': 42.33894971000007,
#   'crime_id': 3052412,
#   'report_number': 1704180257,
#   'address': '15th St & Martin Luther King Jr Blvd'},
#  224: {'X': -83.06570636799995,
#   'Y': 42.442696302000066,
#   'crime_id': 3073795,
#   'report_number': 1706050218,
#   'address': 'E Remington St & Wexford St'},
#  225: {'X': -83.09604461899994,
#   'Y': 42.37665995800006,
#   'crime_id': 3084183,
#   'report_number': 1706290188,
#   'address': 'Taylor St & Woodrow Wilson St'},
#  226: {'X': -82.99576347199995,
#   'Y': 42.42742921200004,
#   'crime_id': 3084343,
#   'report_number': 1706290400,
#   'address': 'Greiner St & Barlow St'},
#  227: {'X': -82.94593787799994,
#   'Y': 42.43143463500007,
#   'crime_id': 3087817,
#   'report_number': 1707070357,
#   'address': 'Moross Rd & Wayburn St'},
#  228: {'X': -83.13973650499997,
#   'Y': 42.36397738000005,
#   'crime_id': 3089736,
#   'report_number': 1707120119,
#   'address': 'Stoepel St & Westfield St'},
#  229: {'X': -82.95663422699994,
#   'Y': 42.416403350000046,
#   'crime_id': 3090765,
#   'report_number': 1707140301,
#   'address': 'Courville St & Wayburn St'},
#  230: {'X': -83.23309219799995,
#   'Y': 42.34683474500007,
#   'crime_id': 3095549,
#   'report_number': 1707250175,
#   'address': 'Sawyer St & Auburn St'},
#  231: {'X': -83.09961545299996,
#   'Y': 42.446726292000044,
#   'crime_id': 3096959,
#   'report_number': 1707280314,
#   'address': 'Andover St & 8 Mile Service Drive'},
#  232: {'X': -83.226732,
#   'Y': 42.41540106700006,
#   'crime_id': 3099272,
#   'report_number': 1708020488,
#   'address': 'Stahelin Ave & W McNichols Rd'},
#  233: {'X': -83.19509819399997,
#   'Y': 42.43418106300004,
#   'crime_id': 3132878,
#   'report_number': 1710210200,
#   'address': 'Coyle St & Vassar Ave'},
#  234: {'X': -83.14280279099995,
#   'Y': 42.352022068000046,
#   'crime_id': 3134174,
#   'report_number': 1710240430,
#   'address': 'Prairie St & Tireman St'},
#  235: {'X': -83.22979027099996,
#   'Y': 42.42983078200007,
#   'crime_id': 3134991,
#   'report_number': 1710260387,
#   'address': 'W 7 Mile Rd & Warwick St'},
#  236: {'X': -83.14280279099995,
#   'Y': 42.352022068000046,
#   'crime_id': 3136538,
#   'report_number': 1710300406,
#   'address': 'Prairie St & Tireman St'},
#  237: {'X': -83.02387507699996,
#   'Y': 42.34828321600002,
#   'crime_id': 3137627,
#   'report_number': 1711020119,
#   'address': 'Campau Farms Cir & Prince Hall Dr'},
#  238: {'X': -82.953741671,
#   'Y': 42.37051616100007,
#   'crime_id': 3138052,
#   'report_number': 1711030174,
#   'address': 'Dickerson St & E Jefferson Ave'},
#  239: {'X': -83.04911658999998,
#   'Y': 42.43345011400004,
#   'crime_id': 3138927,
#   'report_number': 1711100226,
#   'address': 'E 7 Mile Rd & Bloom St'},
#  240: {'X': -83.06069705099996,
#   'Y': 42.34553956400004,
#   'crime_id': 3140757,
#   'report_number': 1711100010,
#   'address': 'Martin Luther King Jr Blvd & Cass Ave'},
#  241: {'X': -83.06864859899997,
#   'Y': 42.41287306600003,
#   'crime_id': 3136074,
#   'report_number': 1710290317,
#   'address': 'Joseph Campau St & E Davison St'},
#  242: {'X': -83.09007405999995,
#   'Y': 42.33629587100006,
#   'crime_id': 3144287,
#   'report_number': 1711140133,
#   'address': 'Martin Luther King Jr Blvd & Maybury Grand St'},
#  243: {'X': -82.979773057,
#   'Y': 42.37862050800004,
#   'crime_id': 3163433,
#   'report_number': 1801070189,
#   'address': 'Mack Ave & Beniteau St'},
#  244: {'X': -83.05500506699997,
#   'Y': 42.360766453000046,
#   'crime_id': 3160277,
#   'report_number': 1712280238,
#   'address': 'E Warren Ave & S I 75 Service Drive'},
#  245: {'X': -83.21194718099997,
#   'Y': 42.41206746900008,
#   'crime_id': 3151280,
#   'report_number': 1712020156,
#   'address': 'Verne St & Gilchrist St'},
#  246: {'X': -83.10511170299998,
#   'Y': 42.36796799500007,
#   'crime_id': 3161540,
#   'report_number': 1801020011,
#   'address': 'W Philadelphia St & Linwood St'},
#  247: {'X': -83.01469260499994,
#   'Y': 42.37883098000003,
#   'crime_id': 3163790,
#   'report_number': 1801080336,
#   'address': 'Van Dyke St & Gratiot Ave'},
#  248: {'X': -83.16099204499993,
#   'Y': 42.38069110300006,
#   'crime_id': 3175483,
#   'report_number': 1802110141,
#   'address': 'Fullerton St & Ilene St'},
#  249: {'X': -83.10273546799993,
#   'Y': 42.37008072200007,
#   'crime_id': 3177335,
#   'report_number': 1802170038,
#   'address': 'Pingree St & La Salle Blvd'},
#  250: {'X': -83.27412196799997,
#   'Y': 42.42903068000004,
#   'crime_id': 3178241,
#   'report_number': 1802190262,
#   'address': 'Appleton St & W 7 Mile Rd'},
#  251: {'X': -83.02450559399993,
#   'Y': 42.44134969200008,
#   'crime_id': 3181561,
#   'report_number': 1802280265,
#   'address': 'E Outer Dr & Van Dyke St'},
#  252: {'X': -82.98410728499994,
#   'Y': 42.43700023300004,
#   'crime_id': 3170739,
#   'report_number': 1801280048,
#   'address': 'Lappin St & Mapleview St'},
#  253: {'X': -83.08294447399999,
#   'Y': 42.384609960000034,
#   'crime_id': 3173731,
#   'report_number': 1802050355,
#   'address': 'Woodward Ave & Edison St'},
#  254: {'X': -83.00924334199993,
#   'Y': 42.42711445200007,
#   'crime_id': 3193170,
#   'report_number': 1803310043,
#   'address': 'Greiner St & Beland St'},
#  255: {'X': -83.06075260299998,
#   'Y': 42.35167725600007,
#   'crime_id': 3182713,
#   'report_number': 1803040020,
#   'address': 'Woodward Ave & W Willis St'},
#  256: {'X': -83.20146220899994,
#   'Y': 42.39924515300004,
#   'crime_id': 3193876,
#   'report_number': 1804020078,
#   'address': 'Forrer St & Chalfonte St'},
#  257: {'X': -83.07891689199994,
#   'Y': 42.37303375600004,
#   'crime_id': 3199982,
#   'report_number': 1804170182,
#   'address': 'Delaware St & 2nd Ave'},
#  258: {'X': -83.20577334499995,
#   'Y': 42.38931616000008,
#   'crime_id': 3190905,
#   'report_number': 1803250158,
#   'address': 'Saint Marys St & Kendall St'},
#  259: {'X': -83.21456827599997,
#   'Y': 42.38674943500007,
#   'crime_id': 3204055,
#   'report_number': 1804270069,
#   'address': 'Schoolcraft St & Longacre St'},
#  260: {'X': -82.94368164799994,
#   'Y': 42.44739363900004,
#   'crime_id': 3214981,
#   'report_number': 1805230097,
#   'address': 'Eastland Dr & Edmore Dr'},
#  261: {'X': -82.97065825599998,
#   'Y': 42.392169762000044,
#   'crime_id': 3217519,
#   'report_number': 1805290230,
#   'address': 'McCoy Cir & Stringham Ct'},
#  262: {'X': -83.01167445599998,
#   'Y': 42.39787675300005,
#   'crime_id': 3225370,
#   'report_number': 1806160215,
#   'address': 'Isham Ave & Edgewood Ave'},
#  263: {'X': -83.12721425599993,
#   'Y': 42.31144861300004,
#   'crime_id': 3228472,
#   'report_number': 1806240040,
#   'address': 'Springwells St & W Vernor Hwy'},
#  264: {'X': -83.18847784899998,
#   'Y': 42.39099128400005,
#   'crime_id': 3238481,
#   'report_number': 1807170004,
#   'address': 'Hubbell St & Intervale St'},
#  265: {'X': -83.13474093699995,
#   'Y': 42.35062162400004,
#   'crime_id': 3240403,
#   'report_number': 1807210058,
#   'address': 'Barton St & Livernois Ave'},
#  266: {'X': -83.23335432999993,
#   'Y': 42.388746800000035,
#   'crime_id': 3250551,
#   'report_number': 1808140076,
#   'address': 'Kendall St & Minock St'},
#  267: {'X': -83.00523456799993,
#   'Y': 42.39314083200002,
#   'crime_id': 3242463,
#   'report_number': 1807260020,
#   'address': 'Harper Ave & Gratiot Ave'},
#  268: {'X': -82.98255388899997,
#   'Y': 42.42772291600005,
#   'crime_id': 3249604,
#   'report_number': 1808110283,
#   'address': 'Greiner St & Gratiot Ave'},
#  269: {'X': -83.13244569499993,
#   'Y': 42.39208902700005,
#   'crime_id': 3230236,
#   'report_number': 1806280068,
#   'address': 'Pasadena St & Dexter Ave'},
#  270: {'X': -83.22054857199998,
#   'Y': 42.37436961900005,
#   'crime_id': 3254050,
#   'report_number': 1808220162,
#   'address': 'Penrod St & Wadsworth St'},
#  271: {'X': -83.11424842999998,
#   'Y': 42.35716630100006,
#   'crime_id': 3256472,
#   'report_number': 1808280096,
#   'address': 'Seebaldt St & Turner St'},
#  272: {'X': -82.95303084999993,
#   'Y': 42.36602664200007,
#   'crime_id': 3250535,
#   'report_number': 1808140048,
#   'address': 'Kitchener St & Freud St'},
#  273: {'X': -83.13709235999991,
#   'Y': 42.34188555600008,
#   'crime_id': 3237808,
#   'report_number': 1807150137,
#   'address': 'Braden St & Kirkwood St'},
#  274: {'X': -83.23977675799993,
#   'Y': 42.406050006000044,
#   'crime_id': 3249704,
#   'report_number': 1808110381,
#   'address': 'Heyden St & Pilgrim St'},
#  275: {'X': -83.04098148599995,
#   'Y': 42.335605480000034,
#   'crime_id': 3243757,
#   'report_number': 1807290057,
#   'address': 'Monroe St & Saint Antoine St'},
#  276: {'X': -83.092610387,
#   'Y': 42.311262629000055,
#   'crime_id': 3241409,
#   'report_number': 1807230313,
#   'address': 'W Fort St & Lansing St'},
#  277: {'X': -82.97642386299998,
#   'Y': 42.41296008000006,
#   'crime_id': 3259914,
#   'report_number': 1809050367,
#   'address': 'E Outer Dr & Coplin St'},
#  278: {'X': -83.14559210599998,
#   'Y': 42.37603234800008,
#   'crime_id': 3259655,
#   'report_number': 1809050133,
#   'address': 'Bryden St & Elmhurst St'},
#  279: {'X': -83.23675857399995,
#   'Y': 42.346804322000025,
#   'crime_id': 3254409,
#   'report_number': 1808230044,
#   'address': 'Vaughan St & Sawyer St'},
#  280: {'X': -83.05055060099994,
#   'Y': 42.442500193000065,
#   'crime_id': 3272486,
#   'report_number': 1810030071,
#   'address': 'Moenart St & Cordova St'},
#  281: {'X': -83.09257394599996,
#   'Y': 42.43098652900005,
#   'crime_id': 3264440,
#   'report_number': 1809130437,
#   'address': 'E Hollywood Ave & Hawthorne St'},
#  282: {'X': -82.99493736999993,
#   'Y': 42.43652060200003,
#   'crime_id': 3267575,
#   'report_number': 1809210063,
#   'address': 'Waltham St & Lappin St'},
#  283: {'X': -83.28364129699997,
#   'Y': 42.41434657900004,
#   'crime_id': 3271038,
#   'report_number': 1809290132,
#   'address': 'Winston St & W McNichols Rd'},
#  284: {'X': -82.95180393699997,
#   'Y': 42.42915402300008,
#   'crime_id': 3274679,
#   'report_number': 1810080184,
#   'address': 'Laing St & Casino St'},
#  285: {'X': -83.02426146499994,
#   'Y': 42.43397794500004,
#   'crime_id': 3276238,
#   'report_number': 1810110390,
#   'address': 'Van Dyke St & E 7 Mile Rd'},
#  286: {'X': -83.18747252099996,
#   'Y': 42.39457688500005,
#   'crime_id': 3276842,
#   'report_number': 1810130186,
#   'address': 'Strathmoor St & Lyndon St'},
#  287: {'X': -82.94649067499995,
#   'Y': 42.41596503300008,
#   'crime_id': 3282785,
#   'report_number': 1810280078,
#   'address': 'McKinney Ave & Kensington Ave'},
#  288: {'X': -82.97642386299998,
#   'Y': 42.41296008000006,
#   'crime_id': 3286603,
#   'report_number': 1811060323,
#   'address': 'E Outer Dr & Coplin St'},
#  289: {'X': -82.94588808899994,
#   'Y': 42.41876701600006,
#   'crime_id': 3291349,
#   'report_number': 1811190048,
#   'address': 'Balfour Rd & Grayton St'},
#  290: {'X': -83.07009470299994,
#   'Y': 42.38212985000007,
#   'crime_id': 3314941,
#   'report_number': 1901200199,
#   'address': 'Hague St & Oakland St'},
#  291: {'X': -83.12171750499994,
#   'Y': 42.36565348100004,
#   'crime_id': 3313988,
#   'report_number': 1901170234,
#   'address': 'Petoskey Ave & Otsego St'},
#  292: {'X': -83.08710740199997,
#   'Y': 42.41812470700007,
#   'crime_id': 3299007,
#   'report_number': 1812090079,
#   'address': 'E McNichols Rd & N I 75 Service Drive'},
#  293: {'X': -83.12203487799998,
#   'Y': 42.393026787000046,
#   'crime_id': 3309241,
#   'report_number': 1901050065,
#   'address': 'W Davison St & Linwood St'},
#  294: {'X': -83.06369597599996,
#   'Y': 42.34616029000005,
#   'crime_id': 3311032,
#   'report_number': 1901090377,
#   'address': '2nd Ave & Brainard St'},
#  295: {'X': -83.22770040099994,
#   'Y': 42.37203749800005,
#   'crime_id': 3311853,
#   'report_number': 1901120023,
#   'address': 'Warwick St & Plymouth Rd'},
#  296: {'X': -83.20308352599994,
#   'Y': 42.43938482400005,
#   'crime_id': 3312866,
#   'report_number': 1901150012,
#   'address': 'Fargo St & Forrer St'},
#  297: {'X': -83.12394737499993,
#   'Y': 42.39046639900005,
#   'crime_id': 3305028,
#   'report_number': 1812240270,
#   'address': 'Tyler St & Lawton St'},
#  298: {'X': -82.99938051,
#   'Y': 42.379494362000045,
#   'crime_id': 3326666,
#   'report_number': 1902240211,
#   'address': 'McClellan St & Carleton St'},
#  299: {'X': -83.06833932599994,
#   'Y': 42.358930145000045,
#   'crime_id': 3344290,
#   'report_number': 1904110100,
#   'address': 'W Kirby St & Cass Ave'},
#  300: {'X': -82.96093289199995,
#   'Y': 42.44375663300008,
#   'crime_id': 3349980,
#   'report_number': 1904250135,
#   'address': 'Rossini Dr & Crusade St'},
#  301: {'X': -83.168725539,
#   'Y': 42.38825644100008,
#   'crime_id': 3344340,
#   'report_number': 1904110180,
#   'address': 'Schoolcraft St & Meyers Rd'},
#  302: {'X': -83.18965355899995,
#   'Y': 42.41994965600002,
#   'crime_id': 3346764,
#   'report_number': 1904170303,
#   'address': 'Hubbell St & W Outer Dr'},
#  303: {'X': -83.10851175299997,
#   'Y': 42.37303965500007,
#   'crime_id': 3341756,
#   'report_number': 1904050071,
#   'address': 'Linwood St & Clairmount St'},
#  304: {'X': -83.04952197099999,
#   'Y': 42.359897043000046,
#   'crime_id': 3364631,
#   'report_number': 1905300095,
#   'address': 'Russell St & E Forest Ave'},
#  305: {'X': -83.25885583299998,
#   'Y': 42.44324295100006,
#   'crime_id': 3365553,
#   'report_number': 1906010120,
#   'address': 'Lahser Rd & 8 Mile Rd'},
#  306: {'X': -83.092103604,
#   'Y': 42.44668575900005,
#   'crime_id': 3350582,
#   'report_number': 1904260306,
#   'address': 'Cardoni St & 8 Mile Service Drive'},
#  307: {'X': -82.94905561999997,
#   'Y': 42.44002574600006,
#   'crime_id': 3370662,
#   'report_number': 1906130128,
#   'address': 'Liberal St & Kelly Rd'},
#  308: {'X': -82.97801776499993,
#   'Y': 42.36348121000003,
#   'crime_id': 3374997,
#   'report_number': 1906240005,
#   'address': 'Saint Clair St & E Jefferson Ave'},
#  309: {'X': -83.19219262299998,
#   'Y': 42.37489834900003,
#   'crime_id': 3385978,
#   'report_number': 1907190028,
#   'address': 'Wadsworth St & Robson St'},
#  310: {'X': -83.16914124299996,
#   'Y': 42.36598184600007,
#   'crime_id': 3352851,
#   'report_number': 1905020111,
#   'address': 'W Chicago St & Appoline'},
#  311: {'X': -83.11947994399995,
#   'Y': 42.422077631000036,
#   'crime_id': 3396188,
#   'report_number': 1908110075,
#   'address': 'Pontchartrain Blvd & Hamilton Rd'},
#  312: {'X': -83.24210484699995,
# ...
#   'address': 'Crusade St & Liberal St'},
#  929: {'X': -83.12239481599994,
#   'Y': 42.30476948000006,
#   'crime_id': 3203099,
#   'report_number': 1804250059,
#   'address': 'Springwells St & Mint St'},
#  930: {'X': -83.16300163999993,
#   'Y': 42.36391736500008,
#   'crime_id': 3210572,
#   'report_number': 1805130029,
#   'address': 'Birwood St & Westfield St'},
#  931: {'X': -83.08729234099997,
#   'Y': 42.42187595200004,
#   'crime_id': 3177889,
#   'report_number': 1802180272,
#   'address': 'Madeira St & Greeley St'},
#  932: {'X': -83.16946830399995,
#   'Y': 42.37557803200008,
#   'crime_id': 3212444,
#   'report_number': 1805170183,
#   'address': 'Wadsworth St & Appoline'},
#  933: {'X': -83.070652076,
#   'Y': 42.353358840000055,
#   'crime_id': 3184108,
#   'report_number': 1803070335,
#   'address': 'Anthony Wayne Dr & W Hancock St'},
#  934: {'X': -83.16300163999993,
#   'Y': 42.36391736500008,
#   'crime_id': 3210748,
#   'report_number': 1805130212,
#   'address': 'Birwood St & Westfield St'},
#  935: {'X': -83.19768429999993,
#   'Y': 42.40517288000007,
#   'crime_id': 3216211,
#   'report_number': 1805260069,
#   'address': 'Prest St & Midland St'},
#  936: {'X': -83.10594050599997,
#   'Y': 42.341800830000075,
#   'crime_id': 3257233,
#   'report_number': 1808290380,
#   'address': 'W Grand Blvd & W Hancock St'},
#  937: {'X': -83.21653962999993,
#   'Y': 42.34336839300004,
#   'crime_id': 3258125,
#   'report_number': 1809010080,
#   'address': 'W Warren Ave & S M 39 Service Drive'},
#  938: {'X': -83.13710857599993,
#   'Y': 42.37633659900007,
#   'crime_id': 3258167,
#   'report_number': 1809010137,
#   'address': 'Nardin Park & Elmhurst St'},
#  939: {'X': -83.06761751599998,
#   'Y': 42.44047905100007,
#   'crime_id': 3191114,
#   'report_number': 1803260030,
#   'address': 'E Outer Dr & Norwood St'},
#  940: {'X': -83.14160109399995,
#   'Y': 42.38405341800007,
#   'crime_id': 3198978,
#   'report_number': 1804140244,
#   'address': 'W Buena Vista St & Santa Rosa Dr'},
#  941: {'X': -83.19287369499993,
#   'Y': 42.40712544500008,
#   'crime_id': 3241082,
#   'report_number': 1807220168,
#   'address': 'Robson St & Pilgrim St'},
#  942: {'X': -83.27830590899998,
#   'Y': 42.44274767600007,
#   'crime_id': 3292871,
#   'report_number': 1811230176,
#   'address': '8 Mile Rd & Telegraph Rd'},
#  943: {'X': -83.10486862499994,
#   'Y': 42.33853738900008,
#   'crime_id': 3258256,
#   'report_number': 1809010219,
#   'address': 'Bangor St & Buchanan St'},
#  944: {'X': -83.21843058199995,
#   'Y': 42.43367101100006,
#   'crime_id': 3301169,
#   'report_number': 1812140307,
#   'address': 'Vassar Ave & Fenmore St'},
#  945: {'X': -83.06145212699995,
#   'Y': 42.363365139000045,
#   'crime_id': 3239533,
#   'report_number': 1807190096,
#   'address': 'Beaubien St & E Ferry St'},
#  946: {'X': -83.18361389299997,
#   'Y': 42.42191656400007,
#   'crime_id': 3334330,
#   'report_number': 1903170273,
#   'address': 'Thatcher St & Stansbury St'},
#  947: {'X': -83.13853183299993,
#   'Y': 42.428059276000056,
#   'crime_id': 3270814,
#   'report_number': 1809280339,
#   'address': 'Margareta St & Oak Dr'},
#  948: {'X': -83.12203487799998,
#   'Y': 42.393026787000046,
#   'crime_id': 3271707,
#   'report_number': 1810010178,
#   'address': 'W Davison St & Linwood St'},
#  949: {'X': -83.218658238,
#   'Y': 42.41908531900003,
#   'crime_id': 3364753,
#   'report_number': 1905300221,
#   'address': 'W Outer Dr & Southfield Service Drive'},
#  950: {'X': -83.19219262299998,
#   'Y': 42.37489834900003,
#   'crime_id': 3339839,
#   'report_number': 1903310140,
#   'address': 'Wadsworth St & Robson St'},
#  951: {'X': -83.16775635899995,
#   'Y': 42.390093173000025,
#   'crime_id': 3352773,
#   'report_number': 1905020068,
#   'address': 'Manor & Kendall St'},
#  952: {'X': -83.22481059599994,
#   'Y': 42.44249018800008,
#   'crime_id': 3389262,
#   'report_number': 1907260186,
#   'address': 'Hessel Ave & Faust Ave'},
#  953: {'X': -83.22599261799998,
#   'Y': 42.41912858400008,
#   'crime_id': 3356399,
#   'report_number': 1905100352,
#   'address': 'W Outer Dr & Avon Ave'},
#  954: {'X': -83.0291185199999,
#   'Y': 42.37270466900002,
#   'crime_id': 3400899,
#   'report_number': 1908220094,
#   'address': 'Mount Elliott St & Frederick St'},
#  955: {'X': -83.18965355899995,
#   'Y': 42.41994965600002,
#   'crime_id': 3373236,
#   'report_number': 1906190296,
#   'address': 'Hubbell St & W Outer Dr'},
#  956: {'X': -83.14248896799995,
#   'Y': 42.37923871100002,
#   'crime_id': 3421510,
#   'report_number': 1910100051,
#   'address': 'Monica St & Cortland St'},
#  957: {'X': -83.11005807299993,
#   'Y': 42.333820926000044,
#   'crime_id': 3381184,
#   'report_number': 1907080084,
#   'address': 'Jackson St & 31st St'},
#  958: {'X': -83.24908133199995,
#   'Y': 42.44185493500004,
#   'crime_id': 3457284,
#   'report_number': 2001110082,
#   'address': 'Hessel Ave & Burt Rd'},
#  959: {'X': -82.95023028999998,
#   'Y': 42.38011411900004,
#   'crime_id': 3387461,
#   'report_number': 1907220344,
#   'address': 'Lakewood St & E Vernor Hwy'},
#  960: {'X': -83.04356531699995,
#   'Y': 42.369880745000046,
#   'crime_id': 3408099,
#   'report_number': 1909080116,
#   'address': 'Chene St & E Ferry St'},
#  961: {'X': -83.06393298899997,
#   'Y': 42.34004243800007,
#   'crime_id': 3425484,
#   'report_number': 1910190289,
#   'address': '4th St & Temple St'},
#  962: {'X': -83.10287064799998,
#   'Y': 42.35936022900006,
#   'crime_id': 3436532,
#   'report_number': 1911160250,
#   'address': 'Lawton St & W Grand Blvd'},
#  963: {'X': -83.12608389599995,
#   'Y': 42.40298205700003,
#   'crime_id': 3443853,
#   'report_number': 1912060128,
#   'address': 'Fenkell St & Normandy St'},
#  964: {'X': -82.99728694399995,
#   'Y': 42.41730426500004,
#   'crime_id': 3070417,
#   'report_number': 1705280329,
#   'address': 'Bradford St & College St'},
#  965: {'X': -83.11936731999998,
#   'Y': 42.36082685400004,
#   'crime_id': 3446675,
#   'report_number': 1912130280,
#   'address': 'Virginia Park St & Grand River Ave'},
#  966: {'X': -83.00223820999997,
#   'Y': 42.43449512700005,
#   'crime_id': 3023606,
#   'report_number': 1702100111,
#   'address': 'E 7 Mile Rd & Annott St'},
#  967: {'X': -83.06413939199997,
#   'Y': 42.351577786000064,
#   'crime_id': 3026458,
#   'report_number': 1702170176,
#   'address': 'Cass Ave & W Canfield St'},
#  968: {'X': -83.17186384999997,
#   'Y': 42.373158430000046,
#   'crime_id': 3037499,
#   'report_number': 1703130024,
#   'address': 'Sorrento St & Plymouth Rd'},
#  969: {'X': -83.05655350199999,
#   'Y': 42.330145422000044,
#   'crime_id': 3117621,
#   'report_number': 1709150124,
#   'address': 'Abbott St & 3rd St'},
#  970: {'X': -82.95007414599996,
#   'Y': 42.42046837100002,
#   'crime_id': 3153435,
#   'report_number': 1712070283,
#   'address': 'Roxbury St & Grayton St'},
#  971: {'X': -83.23839209499994,
#   'Y': 42.41927238500005,
#   'crime_id': 3062430,
#   'report_number': 1705100141,
#   'address': 'Evergreen Rd & Santa Clara Ave'},
#  972: {'X': -83.11291475099993,
#   'Y': 42.291575599000055,
#   'crime_id': 3068135,
#   'report_number': 1705230241,
#   'address': 'Medina St & S Westend St'},
#  973: {'X': -83.13213298299998,
#   'Y': 42.31451487800007,
#   'crime_id': 3164856,
#   'report_number': 1801110298,
#   'address': 'Norman St & Belle St'},
#  974: {'X': -83.06369597599996,
#   'Y': 42.34616029000005,
#   'crime_id': 3184216,
#   'report_number': 1803080045,
#   'address': '2nd Ave & Brainard St'},
#  975: {'X': -83.22253891299994,
#   'Y': 42.35776827600006,
#   'crime_id': 3193117,
#   'report_number': 1803300374,
#   'address': 'Joy Rd & Greenview Ave'},
#  976: {'X': -83.15893574799998,
#   'Y': 42.40972662100006,
#   'crime_id': 3205078,
#   'report_number': 1804300042,
#   'address': 'Puritan St & Kentucky St'},
#  977: {'X': -83.22884885099995,
#   'Y': 42.36726072200002,
#   'crime_id': 3113076,
#   'report_number': 1709040171,
#   'address': 'Orangelawn St & Piedmont St'},
#  978: {'X': -83.13615232199999,
#   'Y': 42.33342047900004,
#   'crime_id': 3156629,
#   'report_number': 1712170109,
#   'address': 'Tarnow St & W I 94 Service Drive'},
#  979: {'X': -83.12534303799998,
#   'Y': 42.30413289900008,
#   'crime_id': 3225238,
#   'report_number': 1806160041,
#   'address': 'Mullane St & Homer St'},
#  980: {'X': -82.99283358699995,
#   'Y': 42.44564265500002,
#   'crime_id': 3244636,
#   'report_number': 1807310091,
#   'address': 'Westphalia St & Bringard Dr'},
#  981: {'X': -82.97801776499993,
#   'Y': 42.36348121000003,
#   'crime_id': 3262212,
#   'report_number': 1809110117,
#   'address': 'Saint Clair St & E Jefferson Ave'},
#  982: {'X': -82.93660350299997,
#   'Y': 42.427614049000056,
#   'crime_id': 3273026,
#   'report_number': 1810040161,
#   'address': 'Worden St & Moross Rd'},
#  983: {'X': -83.07862501199997,
#   'Y': 42.370968256000026,
#   'crime_id': 3293467,
#   'report_number': 1811250119,
#   'address': 'W Bethune St & Bethune Ct'},
#  984: {'X': -83.12171750499994,
#   'Y': 42.36565348100004,
#   'crime_id': 3313988,
#   'report_number': 1901170234,
#   'address': 'Petoskey Ave & Otsego St'},
#  985: {'X': -83.24210484699995,
#   'Y': 42.432051195000035,
#   'crime_id': 3220331,
#   'report_number': 1806040341,
#   'address': 'Votrobeck Dr & Votrobeck Ct'},
#  986: {'X': -82.99693044799993,
#   'Y': 42.374105532000044,
#   'crime_id': 3180144,
#   'report_number': 1802250010,
#   'address': 'Belvidere St & Sylvester St'},
#  987: {'X': -83.26427024499998,
#   'Y': 42.36431287000005,
#   'crime_id': 3271922,
#   'report_number': 1810010416,
#   'address': 'W Chicago St & Beaverland St'},
#  988: {'X': -83.19234207399995,
#   'Y': 42.38231030500003,
#   'crime_id': 3317339,
#   'report_number': 1901280189,
#   'address': 'Glendale St & Robson St'},
#  989: {'X': -83.19234207399995,
#   'Y': 42.38231030500003,
#   'crime_id': 3317786,
#   'report_number': 1901300082,
#   'address': 'Glendale St & Robson St'},
#  990: {'X': -83.28241179099996,
#   'Y': 42.416763866000046,
#   'crime_id': 3338085,
#   'report_number': 1903270068,
#   'address': 'Santa Maria St & Fenton St'},
#  991: {'X': -83.25239993499997,
#   'Y': 42.432870295000036,
#   'crime_id': 3378190,
#   'report_number': 1907010186,
#   'address': 'Westbrook St & Vassar Ave'},
#  992: {'X': -83.04631485499993,
#   'Y': 42.33209402700004,
#   'crime_id': 3378186,
#   'report_number': 1907010183,
#   'address': 'Woodward Ave & Campus Martius'},
#  993: {'X': -82.93365814699995,
#   'Y': 42.364674198000046,
#   'crime_id': 3446456,
#   'report_number': 1912130089,
#   'address': 'Ashland St & Korte St'},
#  994: {'X': -83.04365708799997,
#   'Y': 42.42993723600006,
#   'crime_id': 3395837,
#   'report_number': 1908100166,
#   'address': 'E Hildale St & Mound Rd'},
#  995: {'X': -82.93963848399994,
#   'Y': 42.39635542900004,
#   'crime_id': 3022120,
#   'report_number': 1702060294,
#   'address': 'Waveney St & Haverhill St'},
#  996: {'X': -83.11823595999994,
#   'Y': 42.39276431200005,
#   'crime_id': 3406370,
#   'report_number': 1909040160,
#   'address': 'Tyler St & La Salle Blvd'},
#  997: {'X': -83.14146188099994,
#   'Y': 42.33326535900005,
#   'crime_id': 3407538,
#   'report_number': 1909060364,
#   'address': 'Springwells St & Panama St'},
#  998: {'X': -83.08445226499998,
#   'Y': 42.31846185000006,
#   'crime_id': 3412715,
#   'report_number': 1909180447,
#   'address': 'Howard St & 25th St'},
#  999: {'X': -83.05655350199999,
#   'Y': 42.330145422000044,
#   'crime_id': 3422159,
#   'report_number': 1910110255,
#   'address': 'Abbott St & 3rd St'},
#  1000: {'X': -83.27665725499998,
#   'Y': 42.426608362000024,
#   'crime_id': 3304591,
#   'report_number': 1812230116,
#   'address': 'Clarita St & Dale St'},
#  1001: {'X': -83.13747933899998,
#   'Y': 42.336817360000055,
#   'crime_id': 3465813,
#   'report_number': 2002020259,
#   'address': 'Chopin St & McGraw St'},
#  1002: {'X': -83.15977709199996,
#   'Y': 42.35167478200003,
#   'crime_id': 3397203,
#   'report_number': 1908130315,
#   'address': 'Freda St & Freda Ave'},
#  1003: {'X': -83.09931740199994,
#   'Y': 42.37644885900005,
#   'crime_id': 3405079,
#   'report_number': 1909010049,
#   'address': 'Rosa Parks Blvd & Clairmount St'},
#  1004: {'X': -83.28251040599997,
#   'Y': 42.41923496600003,
#   'crime_id': 3406418,
#   'report_number': 1909040214,
#   'address': 'Fenton St & Bennett St'},
#  1005: {'X': -83.02398839299997,
#   'Y': 42.42674301500005,
#   'crime_id': 3421092,
#   'report_number': 1910090033,
#   'address': 'Van Dyke St & E Nevada St'},
#  1006: {'X': -83.27318080899995,
#   'Y': 42.386889560000036,
#   'crime_id': 3026346,
#   'report_number': 1702160453,
#   'address': 'Dale St & Riverview St'},
#  1007: {'X': -82.93310200799993,
#   'Y': 42.40488243400005,
#   'crime_id': 3014938,
#   'report_number': 1701190002,
#   'address': 'Bishop St & E Warren Ave'},
#  1008: {'X': -83.22134212799993,
#   'Y': 42.35778366700004,
#   'crime_id': 3412001,
#   'report_number': 1909170164,
#   'address': 'Joy Rd & Faust Ave'},
#  1009: {'X': -83.18219961299998,
#   'Y': 42.399804646000064,
#   'crime_id': 3007194,
#   'report_number': 1612280313,
#   'address': 'Chalfonte St & Stansbury St'},
#  1010: {'X': -83.27318080899995,
#   'Y': 42.386889560000036,
#   'crime_id': 3022243,
#   'report_number': 1702070068,
#   'address': 'Dale St & Riverview St'},
#  1011: {'X': -82.95696582499993,
#   'Y': 42.396135886000025,
#   'crime_id': 3024184,
#   'report_number': 1702110249,
#   'address': 'Philip St & E Warren Ave'},
#  1012: {'X': -83.16137301699995,
#   'Y': 42.25853565500006,
#   'crime_id': 3356024,
#   'report_number': 1905090376,
#   'address': 'S Deacon St & Salliotte St'},
#  1014: {'X': -82.96283365999993,
#   'Y': 42.42721551300008,
#   'crime_id': 3020629,
#   'report_number': 1702020215,
#   'address': 'Seymour St & Brock St'},
#  1015: {'X': -83.13431933899994,
#   'Y': 42.300637969000036,
#   'crime_id': 3010211,
#   'report_number': 1701050163,
#   'address': 'Woodmere St & Homer St'},
#  1016: {'X': -83.23751125699994,
#   'Y': 42.40249434700007,
#   'crime_id': 3012896,
#   'report_number': 1701130004,
#   'address': 'Keeler St & Evergreen Rd'},
#  1017: {'X': -83.06942377799999,
#   'Y': 42.35158699000005,
#   'crime_id': 3037675,
#   'report_number': 1703130205,
#   'address': 'Prentis St & 3rd St'},
#  1019: {'X': -83.20436203199995,
#   'Y': 42.43574052400004,
#   'crime_id': 3023673,
#   'report_number': 1702090348,
#   'address': 'Saint Martins Ave & Prevost St'},
#  1021: {'X': -83.10736670399997,
#   'Y': 42.31421370600003,
#   'crime_id': 3052587,
#   'report_number': 1704180383,
#   'address': 'Cadet St & Dragoon St'},
#  1022: {'X': -83.25866913599998,
#   'Y': 42.414746450000045,
#   'crime_id': 3056516,
#   'report_number': 1704280131,
#   'address': 'Rockdale St & W McNichols Rd'},
#  1023: {'X': -83.065562931,
#   'Y': 42.440516685000034,
#   'crime_id': 3060558,
#   'report_number': 1705050325,
#   'address': 'E Outer Dr & Wexford St'},
#  1024: {'X': -82.98255388899997,
#   'Y': 42.42772291600005,
#   'crime_id': 3052942,
#   'report_number': 1704190363,
#   'address': 'Greiner St & Gratiot Ave'},
#  1025: {'X': -83.04952197099999,
#   'Y': 42.359897043000046,
#   'crime_id': 3069062,
#   'report_number': 1705250221,
#   'address': 'Russell St & E Forest Ave'},
#  1026: {'X': -83.16078964199994,
#   'Y': 42.425980713000044,
#   'crime_id': 3042925,
#   'report_number': 1703270060,
#   'address': 'Pickford St & Wyoming St'},
#  1028: {'X': -83.08916444299997,
#   'Y': 42.37188294500004,
#   'crime_id': 3054838,
#   'report_number': 1704250002,
#   'address': 'Virginia Park St & Byron St'},
#  1029: {'X': -83.12636511899994,
#   'Y': 42.329537663000046,
#   'crime_id': 3082170,
#   'report_number': 1706250021,
#   'address': 'Martin St & Parkwood St'},
#  1030: {'X': -83.11884369399995,
#   'Y': 42.33112622400005,
#   'crime_id': 3083462,
#   'report_number': 1706280013,
#   'address': 'Michigan Ave & Military St'},
#  1031: {'X': -83.09212453999999,
#   'Y': 42.370804857000046,
#   'crime_id': 3075994,
#   'report_number': 1706110067,
#   'address': 'Woodrow Wilson St & Virginia Park St'},
#  1032: {'X': -82.96493618099998,
#   'Y': 42.41836641500004,
#   'crime_id': 3088515,
#   'report_number': 1707090241,
#   'address': 'Glenfield Ave & Hayes St'},
#  1033: {'X': -83.16652329399994,
#   'Y': 42.40772688200008,
#   'crime_id': 3072219,
#   'report_number': 1706020005,
#   'address': 'Pilgrim St & Pinehurst St'},
#  1034: {'X': -83.14784746099998,
#   'Y': 42.27313467700003,
#   'crime_id': 3093896,
#   'report_number': 1707210290,
#   'address': 'Melvin St & S Ethel St'},
#  1035: {'X': -83.13743010699994,
#   'Y': 42.40635807600006,
#   'crime_id': 3087415,
#   'report_number': 1707060442,
#   'address': 'Midland St & Holmur St'},
#  ...}
